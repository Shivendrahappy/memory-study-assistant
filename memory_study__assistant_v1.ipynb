# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivendrahappy/memory-study-assistant/blob/main/memory_study__assistant_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
notes = []

title = input ("enter title:")
content = input("enter content : ")

note = {
    "title": title,
    "content": content
}

notes.append(note)

print(notes)
# Out:
# enter title: python notes
# enter content :  Functions are reusable blocks of code.
# [{'title': ' python notes', 'content': ' Functions are reusable blocks of code.'}]

# %%
import json

with open("notes.json", "w") as file:
    json.dump(notes, file)
print("Notes saved successfully")
# Out:
# Notes saved successfully

# %%
with open ("notes.json", "r") as file:
    notes = json.load(file)
print(notes)
# Out:
# [{'title': ' python notes', 'content': ' Functions are reusable blocks of code.'}]

# %%
import json

with open("notes.json", "r") as file:
    notes = json.load(file)

keyword = input("Enter a keyword to search for: ")

matching_notes = []

for note in notes :
  if keyword.lower() in note["content"].lower():
    print ("title:", note["title"])
    print ("content:", note["content"])
    print ("-------")
# Out:
# Enter a keyword to search for: functions
# title:  python notes
# content:  Functions are reusable blocks of code.
# -------
